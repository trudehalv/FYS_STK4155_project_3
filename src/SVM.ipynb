# %%
import random
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score 

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set seed for all 
tf.random.set_seed(42) 
random.seed(42)
np.random.seed(42)

# %%
# Load Fashion MNIST dataset
fashion_mnist = tf.keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
# Adding names to classes, we only have numbers
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Flatten images 
train_images_flat = train_images.reshape(train_images.shape[0], -1)
test_images_flat = test_images.reshape(test_images.shape[0], -1)

# Normalize pixel values
train_images_flat = train_images_flat/255.0
test_images_flat = test_images_flat/255.0

# Scale data
scaler = StandardScaler()
train_images_flat = scaler.fit_transform(train_images_flat)
test_images_flat = scaler.fit_transform(test_images_flat)

print(train_images_flat.shape)
print(test_images_flat.shape)
# Out:
# (60000, 784)
# (10000, 784)

# %%
svm_classifier = SVC(C=1.0, kernel='rbf', gamma=0.0001)
svm_classifier.fit(train_images_flat, train_labels)
# Out:
# SVC(gamma=0.0001)

# %%
# Predict on test data
test_predictions = svm_classifier.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.83      0.81      1000
#            1       0.99      0.95      0.97      1000
#            2       0.75      0.74      0.74      1000
#            3       0.82      0.88      0.85      1000
#            4       0.73      0.78      0.75      1000
#            5       0.93      0.91      0.92      1000
#            6       0.64      0.53      0.58      1000
#            7       0.89      0.92      0.91      1000
#            8       0.95      0.96      0.95      1000
#            9       0.93      0.93      0.93      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
svm_classifier1 = SVC(C=10, kernel='rbf', gamma=0.0001)
svm_classifier1.fit(train_images_flat, train_labels)
# Out:
# SVC(C=10, gamma=0.0001)

# %%
# Predict on test data
test_predictions = svm_classifier1.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      1000
#            1       0.98      0.96      0.97      1000
#            2       0.78      0.79      0.78      1000
#            3       0.84      0.88      0.86      1000
#            4       0.77      0.80      0.78      1000
#            5       0.96      0.94      0.95      1000
#            6       0.70      0.60      0.65      1000
#            7       0.92      0.95      0.93      1000
#            8       0.97      0.97      0.97      1000
#            9       0.96      0.94      0.95      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
svm_classifier2 = SVC(C=100, kernel='rbf', gamma=0.0001)
svm_classifier2.fit(train_images_flat, train_labels)
# Out:
# SVC(C=100, gamma=0.0001)

# %%
# Predict on test data
test_predictions = svm_classifier2.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82      1000
#            1       0.98      0.96      0.97      1000
#            2       0.79      0.82      0.80      1000
#            3       0.86      0.88      0.87      1000
#            4       0.81      0.81      0.81      1000
#            5       0.96      0.95      0.95      1000
#            6       0.71      0.65      0.68      1000
#            7       0.93      0.95      0.94      1000
#            8       0.97      0.95      0.96      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
svm_classifier3 = SVC(C=1000, kernel='rbf', gamma=0.0001)
svm_classifier3.fit(train_images_flat, train_labels)
# Out:
# SVC(C=1000, gamma=0.0001)

# %%
# Predict on test data
test_predictions = svm_classifier3.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82      1000
#            1       0.98      0.97      0.97      1000
#            2       0.78      0.82      0.80      1000
#            3       0.89      0.87      0.88      1000
#            4       0.81      0.82      0.81      1000
#            5       0.95      0.96      0.96      1000
#            6       0.72      0.67      0.70      1000
#            7       0.94      0.96      0.95      1000
#            8       0.97      0.95      0.96      1000
#            9       0.96      0.94      0.95      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
svm_classifier4 = SVC(C=1, kernel='rbf', gamma=0.001)
svm_classifier4.fit(train_images_flat, train_labels)
# Out:
# SVC(C=1, gamma=0.001)

# %%
# Predict on test data
test_predictions = svm_classifier4.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84      1000
#            1       0.99      0.96      0.98      1000
#            2       0.80      0.81      0.81      1000
#            3       0.87      0.89      0.88      1000
#            4       0.80      0.82      0.81      1000
#            5       0.97      0.95      0.96      1000
#            6       0.72      0.65      0.68      1000
#            7       0.93      0.96      0.94      1000
#            8       0.96      0.97      0.97      1000
#            9       0.96      0.95      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
svm_classifier5 = SVC(C=1, kernel='rbf', gamma=0.01)
svm_classifier5.fit(train_images_flat, train_labels)

# %%
# Predict on test data
test_predictions = svm_classifier5.predict(test_images_flat)

# Print classification report
print(classification_report(test_labels, test_predictions))

# Confusion matrix
cm = confusion_matrix(test_labels, test_predictions)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
fig, ax = plt.subplots(figsize=(10,10))
disp.plot(ax=ax)
ax.grid(False)
plt.title(f'Confusion Matrix')
